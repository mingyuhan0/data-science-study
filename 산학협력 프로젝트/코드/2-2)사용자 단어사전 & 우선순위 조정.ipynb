# %% [markdown]
# ## 단어사전에 넣은 키워드 추출
#
# - 고유명사를 뽑기 위한 작업
# - ex) [나는 취업박람회에 가서 직업체험을 경험했다.] --> 취업박람회(취업+박람회), 직업체험(직업+체험)

# %%
from konlpy.tag import Mecab 

import pandas as pd
import numpy as np
import os

# %%
mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

# %%
content = pd.read_csv('using_data/policy_content.csv', encoding='cp949')

# %%
content.head()
# Out:
#    index            name                                        description  \
# 0      0        국민취업지원제도  한국형 실업부조로 고용안전망 사각지대에 있는 취업취약계층에게 취업지원서비스 및 생활...
# 1      1  청년추가고용장려금 지원사업  청년을 정규직으로 추가로 고용한 중소?중견기업에 인건비를 지원함으로써, 양질의 청년...
# 2      3        국민내일배움카드  국민 누구나 일자리에 도움이 되는 훈련을 받을 수 있는 평생능력개발 기반 마련을 위...
# 3      4        청년내일채움공제  중소·중견기업 청년 근로자의 장기근속과 자산형성을 지원하기 위해 청년, 기업, 정부...
# 4      5          청년고용지원                                          청년고용정책 지원
#
#                                              content  \
# 0  1. 취업취약계층에 취업지원\n- 취업지원서비스를 종합적으로 제공하고, 저소득 구직...
# 1  1. 청년 추가채용 1명당 연 최대 900만원을 3년간 지원2. 고용위기 지역 지정...
# 2  1. 국민 누구나 국민내일배움카드 신청 가능\n- 분리 운영되었던 실업자/재직자 내...
# 3  1. 청년 지원내용\n - 청년 본인이 2년간 300만원(매월 12만 5천원)을 적...
# 4  1. 지원내용 청년고용정책 심층 모니터링, 대학일자리센터 컨설팅 및 운영지원, 청년...
#
#                                                  URL
# 0  https://www.youthcenter.go.kr/youngPlcyUnif/yo...
# 1  https://www.youthcenter.go.kr/youngPlcyUnif/yo...
# 2  https://www.youthcenter.go.kr/youngPlcyUnif/yo...
# 3  https://www.youthcenter.go.kr/youngPlcyUnif/yo...
# 4  https://www.youthcenter.go.kr/youngPlcyUnif/yo...

# %%
# 문장 띄어쓰기로 나눠서 명사 추출 - (고유명사 뽑기 위해)

def pos_function(text):
    content_split = []

    for i in text.split():
        content_split.append(mecab.pos(i))

    new_words_list = []
    noun_pos = ['NNG','XSN','NNP']    # 일반명사, 명사 파생 접미사, 고유명사인 애들만 붙이기 
     
    for i in content_split:
        word = ''
        for j in i:
            if j[1] in noun_pos:
                word = word + j[0]
            else:
                break
        new_words_list.append(word)
    
    # 비교용 nouns
    n = mecab.nouns(text)
    
    # 이미 dictionary에 있는 단어 제외하기 
    # 수정 필요 - 한번에 remove가 안돼서 4번 반복
    for i in new_words_list:
        if i in n:
            new_words_list.remove(i)
    for i in new_words_list:
        if i in n:
            new_words_list.remove(i)
    for i in new_words_list:
        if i in n:
            new_words_list.remove(i)                
    for i in new_words_list:
        if i in n:
            new_words_list.remove(i) 
    
    # 공백인 단어 제거
    while '' in new_words_list:            
        if '' in new_words_list:
            new_words_list.remove('')
    
    return new_words_list

# %%
#추출한 명사 list

word_list = []

for i in range(0,1000):
    w = pos_function(content['description'][i])
    word_list.extend(w)
    
word_list
# Out:
# ['기술발전',
#  '등이',
#  '속',
#  '달의',
#  '감면',
#  '중인',
#  '성과보상금',
#  '등의',
#  '등의',
#  '청년들',
#  '참여자들',
#  '청년의',
#  '교육과정',
#  '창직',
#  '근로의',
#  '청년들',
#  '집중적',
#  '성과보상금',
#  '청년들',
#  '선배들',
#  '근로장려금',
#  '체계적',
#  '구직과정',
#  '경제적',
#  '청년들',
#  '지향적',
#  '도전적',
#  '청년의',
#  '경제적',
#  '중소기업인재육성',
#  '유형별',
#  '참여자의',
#  '수준의',
#  '지속가능',
#  '전공과',
#  '직무역량',
#  '지역주도형',
#  '기반의',
#  '함',
#  '매월',
#  '청년예술인',
#  '공공빅데이터',
#  '청년들',
#  '청년들',
#  '성공적',
#  '청년의',
#  '수준의',
#  '청년들',
#  '직무능력중심',
#  '청년들',
#  '이내',
#  '청년들',
#  '구직단념청년들',
#  '가질',
#  '일자리탐색',
#  '등',
#  '기업의',
#  '청년의',
#  '청년취업',
#  '기업주의',
#  '외톨이',
#  '중심의',
#  '한국데이터산업진흥원',
#  '고용친화기업',
#  '자산형성의',
#  '청년들',
#  '인적',
#  '청년의',
#  '함',
#  '청년들',
#  '대상자의',
#  '경력단절여성',
#  '청년의',
#  '함',
#  '미취업자의',
#  '청년취업',
#  '주요과제',
#  '중심의',
#  '청년의',
#  '지역대학생들',
#  '핵심적',
#  '대학의',
#  '함',
#  '청년들',
#  '수준의',
#  '청년들',
#  '형태의',
#  '청년들',
#  '취업지원프로그램',
#  '입주기업',
#  '직무교육',
#  '개인의',
#  '취창업준비생',
#  '실질적',
#  '기업의',
#  '경력단절여성',
#  '전공과',
#  '여성의',
#  '경력단절여성',
#  '종합적',
#  '청년들',
#  '직접',
#  '청년들',
#  '청년의',
#  '국제적',
#  '체계적',
#  '채용설명회',
#  '청년의',
#  '지역현신기관',
#  '유기적',
#  '청년단체들',
#  '직접',
#  '청년의',
#  '취업준비생의',
#  '직업탐색',
#  '공과대학생의',
#  '현장실무역량강화',
#  '청년들',
#  '청년들',
#  '기업의',
#  '청년의',
#  '교양과목',
#  '청년맞춤형',
#  '청년들',
#  '청년들',
#  '안정적',
#  '청년의',
#  '함',
#  '청년의',
#  '등의',
#  '효율적',
#  '직접',
#  '지속가능',
#  '적극적',
#  '개발의',
#  '축이',
#  '분야의',
#  '고급훈련과정',
#  '청년들',
#  '직무교육',
#  '직접',
#  '안정적',
#  '중심의',
#  '교육과정',
#  '청년들',
#  '현재',
#  '현재',
#  '가구의',
#  '청년들',
#  '연수과정',
#  '직무역량',
#  '기업의',
#  '청년의',
#  '청년들',
#  '청년들',
#  '선택의',
#  '시간적',
#  '청년의',
#  '청년들',
#  '근로자들',
#  '대학생들',
#  '등의',
#  '교육과정',
#  '스스로',
#  '발전의',
#  '청년들',
#  '입주기업',
#  '청년의',
#  '청년의',
#  '활성화',
#  '제공',
#  '부산귀환희망',
#  '종합적',
#  '시대의',
#  '안정적',
#  '도움의',
#  '이웃들',
#  '탐방',
#  '대학의',
#  '청년의',
#  '참여자의',
#  '실전면접',
#  '취업정보',
#  '과학기술분야의',
#  '세계적',
#  '수준의',
#  '과학자군',
#  '인력의',
#  '청년들',
#  '국가의',
#  '등의',
#  '청년들',
#  '일자리정보',
#  '청년들',
#  '국제적',
#  '청년들',
#  '시대의',
#  '안정적',
#  '청년들',
#  '체험의',
#  '방향성',
#  '볼',
#  '종합적',
#  '청년취업',
#  '청년들',
#  '기회의',
#  '중심의',
#  '강의권',
#  '청년들',
#  '대학생들',
#  '함',
#  '함',
#  '직무교육',
#  '체험의',
#  '청년들',
#  '교류의',
#  '대상자의',
#  '이내',
#  '등의',
#  '기업의',
#  '취업비용',
#  '활성화',
#  '청년들',
#  '교육의',
#  '향상과정',
#  '형상과정',
#  '안정적',
#  '청년취업',
#  '직접',
#  '핵심분야인',
#  '중심의',
#  '청년의',
#  '지속가능성',
#  '청년들',
#  '총',
#  '한국무역협회',
#  '누비',
#  '구직비용',
#  '중심의',
#  '체계적',
#  '중심의',
#  '의욕',
#  '중인',
#  '청년들',
#  '청년들',
#  '참여청년',
#  '효율적',
#  '예술인들',
#  '청년들',
#  '해소의',
#  '청년들',
#  '선택의',
#  '교육과정',
#  '미취업자들',
#  '전문적',
#  '직무교육',
#  '취업자들',
#  '청년의',
#  '청년들',
#  '상시적',
#  '청년들',
#  '청년들',
#  '재직근로자들',
#  '직무능력향상교육',
#  '국제지도자',
#  '청년들',
#  '기반의',
#  '혁신적',
#  '기업의',
#  '함',
#  '청년들',
#  '청년의',
#  '직무교육',
#  '전공과',
#  '학생들',
#  '청년들',
#  '창농',
#  '직접',
#  '청년의',
#  '체계적',
#  '면접의',
#  '직무교육',
#  '문제의',
#  '청년들',
#  '사회적경제기업',
#  '지속가능',
#  '직접',
#  '실질적',
#  '청년들',
#  '청년들',
#  '국가산업의',
#  '인재들',
#  '종합적',
#  '청년취업',
#  '지속가능',
#  '청년들',
#  '참여청년',
#  '직무교육',
#  '청년의',
#  '청년들',
#  '안정적',
#  '청년들',
#  '교육과정',
#  '청년들',
#  '청년들',
#  '안정적',
#  '청년의',
#  '장병들',
#  '취득여건',
#  '병영생활',
#  '직업적응훈련',
#  '펫카페',
#  '기관의',
#  '학생들',
#  '경제적',
#  '공동훈련센터',
#  '청년들',
#  '대여',
#  '기업맞춤형',
#  '성공적',
#  '신규인력',
#  '수준의',
#  '청년취업',
#  '지역산업맞춤형',
#  '지속가능',
#  '청년의',
#  '청년창업관련',
#  '기업맞춤형',
#  '청년들',
#  '자발적',
#  '관련학과',
#  '기업수요',
#  '혁신인재',
#  '청년의',
#  '구직비용',
#  '지속가능',
#  '면접의',
#  '청년들',
#  '취업정보',
#  '청년의',
#  '국민체력',
#  '효율적',
#  '안정적',
#  '청년취업',
#  '줌',
#  '청년들',
#  '일과',
#  '통합과정',
#  '청년들',
#  '개발협력분야',
#  '지속적',
#  '청년들',
#  '경력단절여성',
#  '등의',
#  '청년들',
#  '속',
#  '문화분야',
#  '대학생들',
#  '간접적',
#  '청년들',
#  '청년의',
#  '여성의',
#  '문화관광해설',
#  '기업의',
#  '청년들',
#  '수준의',
#  '생성',
#  '함',
#  '청년의',
#  '기초연구비',
#  '혁신인재',
#  '미래형자동차',
#  '분야의',
#  '중심의',
#  '참여기업들',
#  '혁신인재',
#  '청년들',
#  '경제적',
#  '청년들',
#  '계속',
#  '상대적',
#  '함',
#  '청년들',
#  '청년들',
#  '청년들',
#  '청년의',
#  '지역혁신',
#  '대학생들',
#  '튜터',
#  '청년들',
#  '경제적',
#  '청년의',
#  '국제적',
#  '청년들',
#  '활성화',
#  '참여청년',
#  '일반',
#  '등의',
#  '청년들',
#  '청년들',
#  '현지주민들',
#  '청소년들',
#  '등의',
#  '종합적',
#  '경제적',
#  '사회적경제기업',
#  '청년들',
#  '지역우수인재',
#  '청년들',
#  '업체의',
#  '과학기술',
#  '주민들',
#  '지속적',
#  '청년들',
#  '실질적',
#  '청년들',
#  '대학의',
#  '청년들',
#  '청년들',
#  '인재들',
#  '청년들',
#  '전문적',
#  '교육과정',
#  '기업의',
#  '교육과정',
#  '실무형',
#  '청년들',
#  '청년의',
#  '봉사단원의',
#  '청년들',
#  '일자리미스매치',
#  '사회진입과정',
#  '분야의',
#  '일자리지원사업',
#  '기능의',
#  '대학의',
#  '청년의',
#  '계층의',
#  '기여',
#  '과학기술혁신인재',
#  '청년고용여건',
#  '우수',
#  '기업의',
#  '청년의',
#  '사회적경제기업조직',
#  '지역적',
#  '심사기준',
#  '근로자들',
#  '스마트그리드',
#  '융복합산업의',
#  '경력목표설정',
#  '사회적',
#  '세대공존시설',
#  '청년들',
#  '사회적경제',
#  '청년들',
#  '지역성과',
#  '분야의',
#  '여성결혼이민자들',
#  '취업정보',
#  '청년들',
#  '구직비용',
#  '기업의',
#  '지역경제활성화',
#  '청년들',
#  '경제적',
#  '기업의',
#  '성장기반',
#  '배터리산업',
#  '대상자의',
#  '전공과',
#  '기업의',
#  '안정적',
#  '여성맞춤형',
#  '종합적',
#  '청년들',
#  '선택의',
#  '청년들',
#  '연',
#  '학령인구',
#  '직접',
#  '청년의',
#  '활성화',
#  '청년들',
#  '도',
#  '통합교육과정',
#  '이론적',
#  '실무형',
#  '청년의',
#  '창작자들',
#  '창작자들',
#  '청년의',
#  '사회적경제기업',
#  '청년활동가의',
#  '청년정책협의체',
#  '역량강화워크숍',
#  '청년들',
#  '사회적경제',
#  '도',
#  '사회적경제',
#  '경제적',
#  '성공적',
#  '미만의',
#  '기업의',
#  '지역경제활성화',
#  '수준의',
#  '지속가능',
#  '활성화',
#  '창의',
#  '청년의',
#  '직접적',
#  '인재의',
#  '청년의',
#  '청년들',
#  '줄',
#  '청년예술인',
#  '직접',
#  '안정적',
#  '청년의',
#  '인재의',
#  '청년취업',
#  '준비자들',
#  '기업의',
#  '발전의',
#  '청년의',
#  '신규인력',
#  '청년들',
#  '교육과정',
#  '청년들',
#  '지친',
#  '청년의',
#  '직무역량',
#  '수준의',
#  '지속가능',
#  '사회진입과정',
#  '분야의',
#  '과제활동',
#  '근로의',
#  '자활기반',
#  '시민들',
#  '구직자간의',
#  '취업의',
#  '분야의',
#  '주체적',
#  '교육의',
#  '기업의',
#  '무역인프라',
#  '대학의',
#  '상호협력',
#  '청년들',
#  '기업의',
#  '대학생들',
#  '대학의',
#  '청년의',
#  '기반의',
#  '청년의',
#  '사회적경제기업',
#  '청년활동가로',
#  '사회적경제기업',
#  '사업기획',
#  '등의',
#  '사회적경제기업',
#  '청년의',
#  '주체들',
#  '경력단절여성의',
#  '취업준비생들',
#  '위주의',
#  '생산적',
#  '특성화학과',
#  '대학의',
#  '청년의',
#  '경제적',
#  '적극적',
#  '실무형',
#  '실무형',
#  '청년의',
#  '유망산업인',
#  '청년들',
#  '사회적경제기업',
#  '청년의',
#  '지속가능',
#  '청년의',
#  '직무교육',
#  '지역주도형',
#  '지속적',
#  '기능안전',
#  '국제적',
#  '창작의',
#  '등의',
#  '청년들',
#  '후계농업인',
#  '청년들',
#  '사회적경제기업',
#  '청년들',
#  '교육과정',
#  '현재',
#  '성공적',
#  '청년의',
#  '농촌지역개발',
#  '청년들',
#  '탐방',
#  '체계적',
#  '일자리센터',
#  '스스로',
#  '후계인력',
#  '금융산업의',
#  '전',
#  '전문적',
#  '이론적',
#  '실무지식',
#  '과학기술인재',
#  '국제적',
#  '시만의',
#  '장학사업',
#  '청년들',
#  '청년들',
#  '중심의',
#  '벤처투자생태계',
#  '청년들',
#  '예술가들',
#  '기업의',
#  '학생들',
#  '차원의',
#  '실무형',
#  '청년창업지원사업',
#  '질적',
#  '공과대학',
#  '성장동력산업',
#  '발굴의',
#  '청년들',
#  '미래형자동차',
#  '기술의',
#  '교육지원프로그램',
#  '지역맞춤형',
#  '일자리미스매치',
#  '지원의',
#  '기능적',
#  '대학의',
#  '청년들',
#  '기업의',
#  '마을주민의',
#  '등의',
#  '정기적',
#  '한시적',
#  '기업의',
#  '종합적',
#  '청년의',
#  '분야의',
#  '농촌체험휴양마을',
#  '청년의',
#  '함',
#  '지방대학',
#  '상호연계',
#  '수급의',
#  '이상의',
#  '수준의',
#  '지속가능',
#  '수준의',
#  '지속가능',
#  '성장동력산업분야',
#  '원',
#  '원',
#  '스마트제조융합학과',
#  '혁신인재',
#  '중인',
#  '체계적',
#  '청년의',
#  '직무교육',
#  '기업의',
#  '청년의',
#  '청년취업난',
#  '청년들',
#  '선택의',
#  '조기취업',
#  '청년의',
#  '이상의',
#  '수준의',
#  '취업정보',
#  '청년들',
#  '취업의',
#  '과소화',
#  '청년들',
#  '청년들',
#  '공공근로사업',
#  '퇴직자들',
#  '체계적',
#  '농업인력',
#  '중심의',
#  '사회적기업',
#  '교육과정',
#  '청년취업',
#  '안정적',
#  '중인',
#  '청년들',
#  '대여',
#  '해양인재육성',
#  '청년들',
#  '청년들',
#  '선택의',
#  '청년들',
#  '청년들',
#  '체계적',
#  '직무교육',
#  '기업의',
#  '청년의',
#  '청년취업',
#  '공과대학',
#  '과제활동',
#  '중심의',
#  '도',
#  '청년의',
#  '중심의',
#  '고도화',
#  '창의',
#  '경제적',
#  '직접',
#  '청년들',
#  '직접',
#  '취업지원프로그램',
#  '지속가능',
#  '구직기간의',
#  '경제적',
#  '고양청년들',
#  '경제적',
#  '체계적',
#  '공학교육혁신센터들',
#  '안정적',
#  '경영목표',
#  '청년들',
#  '실전면접',
#  '성공적',
#  '사회적경제기업',
#  '약정기간',
#  '산업의',
#  '성공적',
#  '실무형',
#  '청년의',
#  '구직비용',
#  '기업의',
#  '안정적',
#  '고도화',
#  '세종시농업',
#  '영리',
#  '대학생들',
#  '직업계고교생의',
#  '기업의',
#  '경력형성의',
#  '필수적',
#  '간의',
#  '미취업자의',
#  '기업의',
#  '기업의',
#  '가능성',
#  '기업의',
#  '기업맞춤형',
#  '혁신적',
#  '교육과정',
#  '실질적',
#  '직접',
#  '청년의',
#  '진출의',
#  '청년의',
#  '등의',
#  '취업준비청년들',
#  '분들',
#  '국민취업지원제도',
#  '분들',
#  '서울시',
#  '종합적',
#  '분야의',
#  '성공적',
#  '통합적인',
#  '전문적',
#  '취업지원프로그램',
#  '집단상담프로그램',
#  '종합',
#  '취업준비생의',
#  '대학의',
#  '전공과정',
#  '기업의',
#  '청년실업문제',
#  '청년들',
#  '체계적',
#  '일자리의',
#  '민간일자리와의',
#  '대학생들',
#  '교육과정',
#  '실질적',
#  '경제적',
#  '청년의',
#  '경제적',
#  '경제적',
#  '취업활동비',
#  '사회적',
#  '불만요인',
#  '시민들',
#  '우수',
#  '정부의',
#  '청년농업인들',
#  '안정적',
#  '체계적',
#  '종합적',
#  '청년의',
#  '직접',
#  '베이스화',
#  '청년의',
#  '이전단계',
#  '학과별',
#  '대학의',
#  '대학의',
#  '청년들',
#  '기업의',
#  '직접',
#  '직접',
#  '연',
#  '직무교육',
#  '직무교육',
#  '수준의',
#  '지속가능',
#  '기업수요의',
#  '현장맞춤형',
#  '실무형',
#  '지역인재들',
#  '채용관련',
#  '고령화',
#  '안정자금',
#  '기업의',
#  '활성화',
#  '우수',
#  '직접적',
#  '지속가능',
#  '수준의',
#  '분야의',
#  '청년의',
#  '사회적',
#  '안정적',
#  '교육과정',
#  '점진적인',
#  '실무형',
#  '공직생활',
#  '청년들',
#  '창농',
#  '이내',
#  '청년의',
#  '지향적',
#  '중인',
#  '안정적',
#  '청년들',
#  '지속가능',
#  '합리적',
#  '직업선택과',
#  '한국고용정보원',
#  '서귀포시의',
#  '뉴딜정책',
#  '에너지밸리클러스터',
#  '혁신성장플랫폼',
#  '지속가능',
#  '산단',
#  '종합적',
#  '청년들',
#  '청년들',
#  '국제적',
#  '사회적경제기업',
#  '지속가능',
#  '지역사회문제',
#  '업사이클',
#  '청년사업장과',
#  '사회적경제기업',
#  '취창업선배들',
#  '청년들',
#  '함',
#  '중소기업취업지원',
#  '산업맞춤형',
#  '일자리창출지원사업',
#  '입주기업의',
#  '전공과',
#  '직무역량',
#  '청년의',
#  '등의',
#  '식품산업의',
#  '안정적',
#  '대여',
#  '대학생들',
#  '청년들',
#  '중인',
#  '직접',
#  '청년들',
#  '중인',
#  '직접',
#  '경제적',
#  '청년들',
#  '청년의',
#  '지속가능',
#  '심적',
#  '지속가능',
#  '취업의',
#  '취업지원서비스인',
#  '청년들',
#  '시민들',
#  '혁신적',
#  '청년들',
#  '청년들',
#  '청년들',
#  '일자리정보',
#  '청년들',
#  '계층의',
#  '등의',
#  '창출의',
#  '구직단념',
#  '청년의',
#  '양성과정',
#  '청년들',
#  '분야의',
#  '가속화',
#  '주요',
#  '청년들',
#  '등의',
#  '대학의',
#  '청년의',
#  '청년의',
#  '나의',
#  '마음의',
#  '분들',
#  '긍정적인',
#  '청년들',
#  '취업지원프로그램']

# %%
#중복제거

word_list
word_unique = list(set(word_list))

# %%
# 과 -> 제거, 의/들/이 -> 빼기
search = "과"
for word in word_unique:
    if word[-1] == search:
        word_unique.remove(word)
        
word_unique.append('관련학과')
word_unique.append('특성화학과')
word_unique.append('스마트제조융합학과')
        
search = '의'
for i, word in enumerate(word_unique):
    if search in word: 
        word_unique[i] = word.rstrip(search)

search = '들'
for i, word in enumerate(word_unique):
    if search in word: 
        word_unique[i] = word.rstrip(search)

search = '이'
for i, word in enumerate(word_unique):
    if search in word: 
        word_unique[i] = word.rstrip(search)

# %%
# 2글자 이하 단어 삭제

results = []

for i in word_unique:
    if len(i) >= 3:
        results.append(i)

# %%
df = pd.DataFrame({'words': results})
df.to_csv('word_dictionary.csv', encoding = 'euc-kr', index = False)

# %% [markdown]
# ## 단어사전 생성

# %%
# 현재 디렉토리 확인

os.getcwd()
# Out:
# 'C:\\Users\\juwan\\Desktop\\산학프로젝트'

# %%
# 사전에 넣기 위해 mecab으로 이동

os.chdir('C:\mecab')

# %%
os.getcwd()
# Out:
# 'C:\\mecab'

# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: C0F9-F0D9
#
#  C:\mecab 디렉터리
#
# 2021-09-17  오전 09:40    <DIR>          .
# 2021-09-17  오전 09:40    <DIR>          ..
# 2017-07-01  오전 01:49         1,908,736 libmecab.dll
# 2017-07-01  오전 01:49            29,940 libmecab.lib
# 2017-07-01  오전 01:49           108,544 mecab.exe
# 2017-07-01  오전 01:48            42,106 mecab.h
# 2017-07-01  오전 01:49             5,272 mecab.lib
# 2017-07-01  오전 01:49           108,544 mecab-cost-train.exe
# 2017-07-01  오전 01:49             5,640 mecab-cost-train.lib
# 2017-07-01  오전 01:49           108,544 mecab-dict-gen.exe
# 2017-07-01  오전 01:49             5,586 mecab-dict-gen.lib
# 2017-07-01  오전 01:49           108,544 mecab-dict-index.exe
# 2017-07-01  오전 01:49             5,640 mecab-dict-index.lib
# 2021-09-17  오전 11:14    <DIR>          mecab-ko-dic
# 2018-07-28  오후 08:12               285 mecabrc
# 2017-07-01  오전 01:49           108,544 mecab-system-eval.exe
# 2017-07-01  오전 01:49             5,666 mecab-system-eval.lib
# 2017-07-01  오전 01:49           108,544 mecab-test-gen.exe
# 2017-07-01  오전 01:49             5,586 mecab-test-gen.lib
# 2021-09-17  오전 09:53    <DIR>          tools
# 2021-09-17  오전 10:21    <DIR>          user-dic
#               16개 파일           2,665,721 바이트
#                5개 디렉터리  94,525,210,624 바이트 남음

# %%
dir = 'C:/Users/juwan/Desktop/산학프로젝트/'

# %%
# 단어사전 불러오기
words = pd.read_csv(dir + 'word_dictionary.csv', encoding='euc-kr')
words
# Out:
#          words
# 0       고급훈련과정
# 1        핵심분야인
# 2         연수과정
# 3       직업계고교생
# 4          핵심적
# ..         ...
# 242       지방대학
# 243     공동훈련센터
# 244       관련학과
# 245      특성화학과
# 246  스마트제조융합학과
#
# [247 rows x 1 columns]

# %%
# 명사 목록 list로 추출
word_lst = words['words']
word_lst
# Out:
# 0         고급훈련과정
# 1          핵심분야인
# 2           연수과정
# 3         직업계고교생
# 4            핵심적
#          ...
# 242         지방대학
# 243       공동훈련센터
# 244         관련학과
# 245        특성화학과
# 246    스마트제조융합학과
# Name: words, Length: 247, dtype: object

# %%
# 등록할 단어 목록 list
word_list = word_lst

# %%
# 종성여부를 판단하기 위한 라이브러리 설치와 판단하는 함수
#jamo 라이브러리 설치
# !pip install jamo
# Out:
# Collecting jamo
#   Downloading https://files.pythonhosted.org/packages/ac/cc/49812faae67f9a24be6ddaf58a2cf7e8c3cbfcf5b762d9414f7103d2ea2c/jamo-0.4.1-py3-none-any.whl
# Installing collected packages: jamo
# Successfully installed jamo-0.4.1

# %%
#종성 여부를 판단하는 함수
from jamo import h2j, j2hcj


def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
# nnp.csv에 단어 추가

with open("./user-dic/nnp.csv", 'r', encoding='utf-8') as f:
    file_data = f.readlines()

word_list = word_lst

for word in word_list:
    jongsung_TF = get_jongsung_TF(word)

    line = '{},,,,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)

    file_data.append(line)

# %%
with open("./user-dic/nnp.csv", 'w', encoding='utf-8') as f: 
    for line in file_data: 
        f.write(line)

# %%
with open("./user-dic/nnp.csv", 'r', encoding='utf-8') as f: 
    file_new = f.readlines() 
file_new

# 여기서 주피터 끄고 확인
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '고급훈련과정,,,,NNP,*,T,고급훈련과정,*,*,*,*,*\n',
#  '핵심분야인,,,,NNP,*,T,핵심분야인,*,*,*,*,*\n',
#  '연수과정,,,,NNP,*,T,연수과정,*,*,*,*,*\n',
#  '직업계고교생,,,,NNP,*,T,직업계고교생,*,*,*,*,*\n',
#  '핵심적,,,,NNP,*,T,핵심적,*,*,*,*,*\n',
#  '공과대학,,,,NNP,*,T,공과대학,*,*,*,*,*\n',
#  '직업탐색,,,,NNP,*,T,직업탐색,*,*,*,*,*\n',
#  '기업맞춤형,,,,NNP,*,T,기업맞춤형,*,*,*,*,*\n',
#  '상대적,,,,NNP,*,T,상대적,*,*,*,*,*\n',
#  '부산귀환희망,,,,NNP,*,T,부산귀환희망,*,*,*,*,*\n',
#  '입주기업,,,,NNP,*,T,입주기업,*,*,*,*,*\n',
#  '청년활동가로,,,,NNP,*,F,청년활동가로,*,*,*,*,*\n',
#  '안정적,,,,NNP,*,T,안정적,*,*,*,*,*\n',
#  '성공적,,,,NNP,*,T,성공적,*,*,*,*,*\n',
#  '시간적,,,,NNP,*,T,시간적,*,*,*,*,*\n',
#  '청년고용여건,,,,NNP,*,T,청년고용여건,*,*,*,*,*\n',
#  '직업적응훈련,,,,NNP,*,T,직업적응훈련,*,*,*,*,*\n',
#  '미취업자,,,,NNP,*,F,미취업자,*,*,*,*,*\n',
#  '구직과정,,,,NNP,*,T,구직과정,*,*,*,*,*\n',
#  '청년맞춤형,,,,NNP,*,T,청년맞춤형,*,*,*,*,*\n',
#  '채용설명회,,,,NNP,*,F,채용설명회,*,*,*,*,*\n',
#  '필수적,,,,NNP,*,T,필수적,*,*,*,*,*\n',
#  '안정자금,,,,NNP,*,T,안정자금,*,*,*,*,*\n',
#  '기업수요,,,,NNP,*,F,기업수요,*,*,*,*,*\n',
#  '고도화,,,,NNP,*,F,고도화,*,*,*,*,*\n',
#  '취업자,,,,NNP,*,F,취업자,*,*,*,*,*\n',
#  '통합교육과정,,,,NNP,*,T,통합교육과정,*,*,*,*,*\n',
#  '혁신적,,,,NNP,*,T,혁신적,*,*,*,*,*\n',
#  '국민체력,,,,NNP,*,T,국민체력,*,*,*,*,*\n',
#  '공학교육혁신센터,,,,NNP,*,F,공학교육혁신센터,*,*,*,*,*\n',
#  '강의권,,,,NNP,*,T,강의권,*,*,*,*,*\n',
#  '국가산업,,,,NNP,*,T,국가산업,*,*,*,*,*\n',
#  '집중적,,,,NNP,*,T,집중적,*,*,*,*,*\n',
#  '기능적,,,,NNP,*,T,기능적,*,*,*,*,*\n',
#  '지역주도형,,,,NNP,*,T,지역주도형,*,*,*,*,*\n',
#  '벤처투자생태계,,,,NNP,*,F,벤처투자생태계,*,*,*,*,*\n',
#  '지역경제활성화,,,,NNP,*,F,지역경제활성화,*,*,*,*,*\n',
#  '불만요인,,,,NNP,*,T,불만요인,*,*,*,*,*\n',
#  '기초연구비,,,,NNP,*,F,기초연구비,*,*,*,*,*\n',
#  '사업기획,,,,NNP,*,T,사업기획,*,*,*,*,*\n',
#  '주요과제,,,,NNP,*,T,주요과제,*,*,*,*,*\n',
#  '실무형,,,,NNP,*,T,실무형,*,*,*,*,*\n',
#  '사회적경제,,,,NNP,*,T,사회적경제,*,*,*,*,*\n',
#  '일자리창출지원사업,,,,NNP,*,T,일자리창출지원사업,*,*,*,*,*\n',
#  '사회진입과정,,,,NNP,*,T,사회진입과정,*,*,*,*,*\n',
#  '참여기업,,,,NNP,*,T,참여기업,*,*,*,*,*\n',
#  '세대공존시설,,,,NNP,*,T,세대공존시설,*,*,*,*,*\n',
#  '취업지원프로그램,,,,NNP,*,T,취업지원프로그램,*,*,*,*,*\n',
#  '실전면접,,,,NNP,*,T,실전면접,*,*,*,*,*\n',
#  '학과별,,,,NNP,*,T,학과별,*,*,*,*,*\n',
#  '지향적,,,,NNP,*,T,지향적,*,*,*,*,*\n',
#  '과학기술분야,,,,NNP,*,F,과학기술분야,*,*,*,*,*\n',
#  '일자리탐색,,,,NNP,*,T,일자리탐색,*,*,*,*,*\n',
#  '여성결혼이민자,,,,NNP,*,F,여성결혼이민자,*,*,*,*,*\n',
#  '입주기업,,,,NNP,*,T,입주기업,*,*,*,*,*\n',
#  '취업준비생,,,,NNP,*,T,취업준비생,*,*,*,*,*\n',
#  '도전적,,,,NNP,*,T,도전적,*,*,*,*,*\n',
#  '한국고용정보원,,,,NNP,*,T,한국고용정보원,*,*,*,*,*\n',
#  '취창업준비생,,,,NNP,*,T,취창업준비생,*,*,*,*,*\n',
#  '준비자,,,,NNP,*,F,준비자,*,*,*,*,*\n',
#  '국민취업지원제도,,,,NNP,*,F,국민취업지원제도,*,*,*,*,*\n',
#  '성장동력산업분야,,,,NNP,*,F,성장동력산업분야,*,*,*,*,*\n',
#  '취업정보,,,,NNP,*,F,취업정보,*,*,*,*,*\n',
#  '업사이클,,,,NNP,*,T,업사이클,*,*,*,*,*\n',
#  '지역사회문제,,,,NNP,*,T,지역사회문제,*,*,*,*,*\n',
#  '개발협력분야,,,,NNP,*,F,개발협력분야,*,*,*,*,*\n',
#  '자산형성,,,,NNP,*,T,자산형성,*,*,*,*,*\n',
#  '지역현신기관,,,,NNP,*,T,지역현신기관,*,*,*,*,*\n',
#  '과학기술인재,,,,NNP,*,T,과학기술인재,*,*,*,*,*\n',
#  '채용관련,,,,NNP,*,T,채용관련,*,*,*,*,*\n',
#  '과학기술,,,,NNP,*,T,과학기술,*,*,*,*,*\n',
#  '고령화,,,,NNP,*,F,고령화,*,*,*,*,*\n',
#  '경력단절여성,,,,NNP,*,T,경력단절여성,*,*,*,*,*\n',
#  '청소년,,,,NNP,*,T,청소년,*,*,*,*,*\n',
#  '경력단절여성,,,,NNP,*,T,경력단절여성,*,*,*,*,*\n',
#  '사회적경제기업,,,,NNP,*,T,사회적경제기업,*,*,*,*,*\n',
#  '후계인력,,,,NNP,*,T,후계인력,*,*,*,*,*\n',
#  '지역맞춤형,,,,NNP,*,T,지역맞춤형,*,*,*,*,*\n',
#  '향상과정,,,,NNP,*,T,향상과정,*,*,*,*,*\n',
#  '무역인프라,,,,NNP,*,F,무역인프라,*,*,*,*,*\n',
#  '산업맞춤형,,,,NNP,*,T,산업맞춤형,*,*,*,*,*\n',
#  '지역적,,,,NNP,*,T,지역적,*,*,*,*,*\n',
#  '중소기업인재육성,,,,NNP,*,T,중소기업인재육성,*,*,*,*,*\n',
#  '농촌지역개발,,,,NNP,*,T,농촌지역개발,*,*,*,*,*\n',
#  '실무지식,,,,NNP,*,T,실무지식,*,*,*,*,*\n',
#  '기술발전,,,,NNP,*,T,기술발전,*,*,*,*,*\n',
#  '청년취업난,,,,NNP,*,T,청년취업난,*,*,*,*,*\n',
#  '장학사업,,,,NNP,*,T,장학사업,*,*,*,*,*\n',
#  '병영생활,,,,NNP,*,T,병영생활,*,*,*,*,*\n',
#  '미래형자동차,,,,NNP,*,F,미래형자동차,*,*,*,*,*\n',
#  '혁신성장플랫폼,,,,NNP,*,T,혁신성장플랫폼,*,*,*,*,*\n',
#  '사회적경제기업조직,,,,NNP,*,T,사회적경제기업조직,*,*,*,*,*\n',
#  '문화분야,,,,NNP,*,F,문화분야,*,*,*,*,*\n',
#  '공직생활,,,,NNP,*,T,공직생활,*,*,*,*,*\n',
#  '직무능력향상교육,,,,NNP,*,T,직무능력향상교육,*,*,*,*,*\n',
#  '여성맞춤형,,,,NNP,*,T,여성맞춤형,*,*,*,*,*\n',
#  '취업비용,,,,NNP,*,T,취업비용,*,*,*,*,*\n',
#  '공공근로사업,,,,NNP,*,T,공공근로사업,*,*,*,*,*\n',
#  '유형별,,,,NNP,*,T,유형별,*,*,*,*,*\n',
#  '교양과목,,,,NNP,*,T,교양과목,*,*,*,*,*\n',
#  '구직기간,,,,NNP,*,T,구직기간,*,*,*,*,*\n',
#  '구직단념,,,,NNP,*,T,구직단념,*,*,*,*,*\n',
#  '일자리미스매치,,,,NNP,*,F,일자리미스매치,*,*,*,*,*\n',
#  '구직단념청년,,,,NNP,*,T,구직단념청년,*,*,*,*,*\n',
#  '대상자,,,,NNP,*,F,대상자,*,*,*,*,*\n',
#  '에너지밸리클러스터,,,,NNP,*,F,에너지밸리클러스터,*,*,*,*,*\n',
#  '역량강화워크숍,,,,NNP,*,T,역량강화워크숍,*,*,*,*,*\n',
#  '지역혁신,,,,NNP,*,T,지역혁신,*,*,*,*,*\n',
#  '통합적인,,,,NNP,*,T,통합적인,*,*,*,*,*\n',
#  '일자리센터,,,,NNP,*,F,일자리센터,*,*,*,*,*\n',
#  '경력형성,,,,NNP,*,T,경력형성,*,*,*,*,*\n',
#  '지역우수인재,,,,NNP,*,T,지역우수인재,*,*,*,*,*\n',
#  '근로장려금,,,,NNP,*,T,근로장려금,*,*,*,*,*\n',
#  '참여청년,,,,NNP,*,T,참여청년,*,*,*,*,*\n',
#  '과학기술혁신인재,,,,NNP,*,T,과학기술혁신인재,*,*,*,*,*\n',
#  '후계농업인,,,,NNP,*,T,후계농업인,*,*,*,*,*\n',
#  '활성화,,,,NNP,*,F,활성화,*,*,*,*,*\n',
#  '국제적,,,,NNP,*,T,국제적,*,*,*,*,*\n',
#  '과학자군,,,,NNP,*,T,과학자군,*,*,*,*,*\n',
#  '경력목표설정,,,,NNP,*,T,경력목표설정,*,*,*,*,*\n',
#  '일자리정보,,,,NNP,*,F,일자리정보,*,*,*,*,*\n',
#  '형상과정,,,,NNP,*,T,형상과정,*,*,*,*,*\n',
#  '농업인력,,,,NNP,*,T,농업인력,*,*,*,*,*\n',
#  '재직근로자,,,,NNP,*,F,재직근로자,*,*,*,*,*\n',
#  '실질적,,,,NNP,*,T,실질적,*,*,*,*,*\n',
#  '상호연계,,,,NNP,*,F,상호연계,*,*,*,*,*\n',
#  '사회적기업,,,,NNP,*,T,사회적기업,*,*,*,*,*\n',
#  '교육과정,,,,NNP,*,T,교육과정,*,*,*,*,*\n',
#  '참여자,,,,NNP,*,F,참여자,*,*,*,*,*\n',
#  '경영목표,,,,NNP,*,F,경영목표,*,*,*,*,*\n',
#  '양성과정,,,,NNP,*,T,양성과정,*,*,*,*,*\n',
#  '배터리산업,,,,NNP,*,T,배터리산업,*,*,*,*,*\n',
#  '지역산업맞춤형,,,,NNP,*,T,지역산업맞춤형,*,*,*,*,*\n',
#  '혁신인재,,,,NNP,*,T,혁신인재,*,*,*,*,*\n',
#  '성장동력산업,,,,NNP,*,T,성장동력산업,*,*,*,*,*\n',
#  '심사기준,,,,NNP,*,T,심사기준,*,*,*,*,*\n',
#  '유망산업인,,,,NNP,*,T,유망산업인,*,*,*,*,*\n',
#  '창작자,,,,NNP,*,F,창작자,*,*,*,*,*\n',
#  '집단상담프로그램,,,,NNP,*,T,집단상담프로그램,*,*,*,*,*\n',
#  '한국데이터산업진흥원,,,,NNP,*,T,한국데이터산업진흥원,*,*,*,*,*\n',
#  '청년창업관련,,,,NNP,*,T,청년창업관련,*,*,*,*,*\n',
#  '봉사단원,,,,NNP,*,T,봉사단원,*,*,*,*,*\n',
#  '현지주민,,,,NNP,*,T,현지주민,*,*,*,*,*\n',
#  '성장기반,,,,NNP,*,T,성장기반,*,*,*,*,*\n',
#  '합리적,,,,NNP,*,T,합리적,*,*,*,*,*\n',
#  '방향성,,,,NNP,*,T,방향성,*,*,*,*,*\n',
#  '구직자간,,,,NNP,*,T,구직자간,*,*,*,*,*\n',
#  '지역인재,,,,NNP,*,T,지역인재,*,*,*,*,*\n',
#  '청년활동가,,,,NNP,*,F,청년활동가,*,*,*,*,*\n',
#  '금융산업,,,,NNP,*,T,금융산업,*,*,*,*,*\n',
#  '융복합산업,,,,NNP,*,T,융복합산업,*,*,*,*,*\n',
#  '취득여건,,,,NNP,*,T,취득여건,*,*,*,*,*\n',
#  '취업지원서비스인,,,,NNP,*,T,취업지원서비스인,*,*,*,*,*\n',
#  '과제활동,,,,NNP,*,T,과제활동,*,*,*,*,*\n',
#  '중소기업취업지원,,,,NNP,*,T,중소기업취업지원,*,*,*,*,*\n',
#  '고양청년,,,,NNP,*,T,고양청년,*,*,*,*,*\n',
#  '공과대학생,,,,NNP,*,T,공과대학생,*,*,*,*,*\n',
#  '생산적,,,,NNP,*,T,생산적,*,*,*,*,*\n',
#  '기능안전,,,,NNP,*,T,기능안전,*,*,*,*,*\n',
#  '구직비용,,,,NNP,*,T,구직비용,*,*,*,*,*\n',
#  '직무능력중심,,,,NNP,*,T,직무능력중심,*,*,*,*,*\n',
#  '청년예술인,,,,NNP,*,T,청년예술인,*,*,*,*,*\n',
#  '문화관광해설,,,,NNP,*,T,문화관광해설,*,*,*,*,*\n',
#  '점진적인,,,,NNP,*,T,점진적인,*,*,*,*,*\n',
#  '취창업선배,,,,NNP,*,T,취창업선배,*,*,*,*,*\n',
#  '기업주,,,,NNP,*,F,기업주,*,*,*,*,*\n',
#  '신규인력,,,,NNP,*,T,신규인력,*,*,*,*,*\n',
#  '전문적,,,,NNP,*,T,전문적,*,*,*,*,*\n',
#  '청년실업문제,,,,NNP,*,T,청년실업문제,*,*,*,*,*\n',
#  '사회적,,,,NNP,*,T,사회적,*,*,*,*,*\n',
#  '학령인구,,,,NNP,*,F,학령인구,*,*,*,*,*\n',
#  '자발적,,,,NNP,*,T,자발적,*,*,*,*,*\n',
#  '직접적,,,,NNP,*,T,직접적,*,*,*,*,*\n',
#  '자활기반,,,,NNP,*,T,자활기반,*,*,*,*,*\n',
#  '지속가능,,,,NNP,*,T,지속가능,*,*,*,*,*\n',
#  '한국무역협회,,,,NNP,*,F,한국무역협회,*,*,*,*,*\n',
#  '취업활동비,,,,NNP,*,F,취업활동비,*,*,*,*,*\n',
#  '예술인,,,,NNP,*,T,예술인,*,*,*,*,*\n',
#  '청년창업지원사업,,,,NNP,*,T,청년창업지원사업,*,*,*,*,*\n',
#  '간접적,,,,NNP,*,T,간접적,*,*,*,*,*\n',
#  '체계적,,,,NNP,*,T,체계적,*,*,*,*,*\n',
#  '가속화,,,,NNP,*,F,가속화,*,*,*,*,*\n',
#  '과소화,,,,NNP,*,F,과소화,*,*,*,*,*\n',
#  '공공빅데이터,,,,NNP,*,F,공공빅데이터,*,*,*,*,*\n',
#  '청년농업인,,,,NNP,*,T,청년농업인,*,*,*,*,*\n',
#  '청년취업,,,,NNP,*,T,청년취업,*,*,*,*,*\n',
#  '이론적,,,,NNP,*,T,이론적,*,*,*,*,*\n',
#  '민간일자리와,,,,NNP,*,F,민간일자리와,*,*,*,*,*\n',
#  '참여자,,,,NNP,*,F,참여자,*,*,*,*,*\n',
#  '일자리지원사업,,,,NNP,*,T,일자리지원사업,*,*,*,*,*\n',
#  '이전단계,,,,NNP,*,F,이전단계,*,*,*,*,*\n',
#  '직무역량,,,,NNP,*,T,직무역량,*,*,*,*,*\n',
#  '교육지원프로그램,,,,NNP,*,T,교육지원프로그램,*,*,*,*,*\n',
#  '경제적,,,,NNP,*,T,경제적,*,*,*,*,*\n',
#  '한시적,,,,NNP,*,T,한시적,*,*,*,*,*\n',
#  '세계적,,,,NNP,*,T,세계적,*,*,*,*,*\n',
#  '취업준비청년,,,,NNP,*,T,취업준비청년,*,*,*,*,*\n',
#  '유기적,,,,NNP,*,T,유기적,*,*,*,*,*\n',
#  '근로자,,,,NNP,*,F,근로자,*,*,*,*,*\n',
#  '펫카페,,,,NNP,*,T,펫카페,*,*,*,*,*\n',
#  '청년단체,,,,NNP,*,T,청년단체,*,*,*,*,*\n',
#  '뉴딜정책,,,,NNP,*,T,뉴딜정책,*,*,*,*,*\n',
#  '청년정책협의체,,,,NNP,*,T,청년정책협의체,*,*,*,*,*\n',
#  '가능성,,,,NNP,*,T,가능성,*,*,*,*,*\n',
#  '조기취업,,,,NNP,*,T,조기취업,*,*,*,*,*\n',
#  '적극적,,,,NNP,*,T,적극적,*,*,*,*,*\n',
#  '직무교육,,,,NNP,*,T,직무교육,*,*,*,*,*\n',
#  '긍정적인,,,,NNP,*,T,긍정적인,*,*,*,*,*\n',
#  '지역대학생,,,,NNP,*,T,지역대학생,*,*,*,*,*\n',
#  '일자리,,,,NNP,*,F,일자리,*,*,*,*,*\n',
#  '해양인재육성,,,,NNP,*,T,해양인재육성,*,*,*,*,*\n',
#  '상호협력,,,,NNP,*,T,상호협력,*,*,*,*,*\n',
#  '효율적,,,,NNP,*,T,효율적,*,*,*,*,*\n',
#  '주체적,,,,NNP,*,T,주체적,*,*,*,*,*\n',
#  '정기적,,,,NNP,*,T,정기적,*,*,*,*,*\n',
#  '국제지도자,,,,NNP,*,F,국제지도자,*,*,*,*,*\n',
#  '현장맞춤형,,,,NNP,*,T,현장맞춤형,*,*,*,*,*\n',
#  '전공과정,,,,NNP,*,T,전공과정,*,*,*,*,*\n',
#  '성과보상금,,,,NNP,*,T,성과보상금,*,*,*,*,*\n',
#  '대학생,,,,NNP,*,T,대학생,*,*,*,*,*\n',
#  '종합적,,,,NNP,*,T,종합적,*,*,*,*,*\n',
#  '베이스화,,,,NNP,*,F,베이스화,*,*,*,*,*\n',
#  '서귀포시,,,,NNP,*,F,서귀포시,*,*,*,*,*\n',
#  '상시적,,,,NNP,*,T,상시적,*,*,*,*,*\n',
#  '기업수요,,,,NNP,*,F,기업수요,*,*,*,*,*\n',
#  '통합과정,,,,NNP,*,T,통합과정,*,*,*,*,*\n',
#  '스마트그리드,,,,NNP,*,F,스마트그리드,*,*,*,*,*\n',
#  '현장실무역량강화,,,,NNP,*,F,현장실무역량강화,*,*,*,*,*\n',
#  '고용친화기업,,,,NNP,*,T,고용친화기업,*,*,*,*,*\n',
#  '약정기간,,,,NNP,*,T,약정기간,*,*,*,*,*\n',
#  '스스로,,,,NNP,*,F,스스로,*,*,*,*,*\n',
#  '세종시농업,,,,NNP,*,T,세종시농업,*,*,*,*,*\n',
#  '미취업자,,,,NNP,*,F,미취업자,*,*,*,*,*\n',
#  '취업준비생,,,,NNP,*,T,취업준비생,*,*,*,*,*\n',
#  '예술가,,,,NNP,*,F,예술가,*,*,*,*,*\n',
#  '식품산업,,,,NNP,*,T,식품산업,*,*,*,*,*\n',
#  '농촌체험휴양마을,,,,NNP,*,T,농촌체험휴양마을,*,*,*,*,*\n',
#  '지속적,,,,NNP,*,T,지속적,*,*,*,*,*\n',
#  '퇴직자,,,,NNP,*,F,퇴직자,*,*,*,*,*\n',
#  '지속가능성,,,,NNP,*,T,지속가능성,*,*,*,*,*\n',
#  '서울시,,,,NNP,*,F,서울시,*,*,*,*,*\n',
#  '마을주민,,,,NNP,*,T,마을주민,*,*,*,*,*\n',
#  '지방대학,,,,NNP,*,T,지방대학,*,*,*,*,*\n',
#  '공동훈련센터,,,,NNP,*,F,공동훈련센터,*,*,*,*,*\n',
#  '관련학과,,,,NNP,*,F,관련학과,*,*,*,*,*\n',
#  '특성화학과,,,,NNP,*,F,특성화학과,*,*,*,*,*\n',
#  '스마트제조융합학과,,,,NNP,*,F,스마트제조융합학과,*,*,*,*,*\n']

# %%
# 컴파일 후 확인

policy_content = pd.read_csv(dir + 'using_data/policy_content.csv', encoding='cp949')

# %%
from konlpy.tag import Mecab

# %%
# 잘 등록되었나 확인

text = policy_content['description'][36]

print(text)
print()
print(mecab.nouns(text))
# Out:
# 주변에 괜찮은 중소기업이 많다는 것을 홍보하기 위해서 정부·지자체에서 인증한 좋은 중소기업 정보를 통합 플랫폼을 통해 유형별로 제공
#
# ['주변', '중소기업', '것', '홍보', '정부', '지자체', '인증', '중소기업', '정보', '통합', '플랫폼', '유형', '제공']

# %% [markdown]
# ## 단어사전 우선순위 변경

# %%
with open('C:/Mecab/mecab-ko-dic/user-nnp.csv', 'r', encoding = 'utf-8') as f:
    user_nnp = f.readlines()

temp = []
for i in user_nnp:
    temp.append(i.split(','))

# 4번째 열의 숫자가 단어의 가중치 - 낮을수록 우선순위가 높음(반비례)
user_nnp = []    
for i in temp:
    i[3] = '0'
    user_nnp.append(','.join(i))

with open('C:/Mecab/mecab-ko-dic/user-nnp.csv', 'w', encoding = 'utf-8') as f:
    for line in user_nnp: 
        f.write(line)

# 주피터 끄고 컴파일 진행
